# %%
from model.DecisionTree import DecisionTree
from model.DNN import DNN
from model.NaiveBayes import NaiveBayes
from model.SVM import SVM
import numpy as np
import jieba
from transformers import BertTokenizer, BertForSequenceClassification
import torch


def get_text_encoding(texts, dictionary):
    # texts: [text1, text2, ...]
    # dictionary: [word1, word2, ....]

    encoding_size = len(dictionary)
    text_encoding = np.zeros((len(texts), encoding_size))
    for textId in range(len(texts)):
        words = set(jieba.cut(texts[textId]))
        for word in words:
            for dicId  in range(encoding_size):
                if word == dictionary[dicId]:
                    text_encoding[textId, dicId] = 1
                    break
            
    return text_encoding


dictionary = []
with open('dictionary.txt', 'r') as file:
    for line in file:
        dictionary.append(line.strip())
print(dictionary)


decision_tree = DecisionTree()
naive_bayes = NaiveBayes()
dnn = DNN()

decision_tree.load('param/decision_tree_model.pth')
naive_bayes.load('param/naive_bayes_model.pth')
dnn.load('param/dnn_model.pth')

model_name = './bert-base-chinese'
tokenizer = BertTokenizer.from_pretrained(model_name)
# model = BertForSequenceClassification.from_pretrained(model_name, num_labels=2).to(device)
model = BertForSequenceClassification.from_pretrained('./bert-param')


def predict(text):
  
    encoding = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    output = model(**encoding)
    predicted_label = torch.argmax(output.logits, dim=1).item()

    text_encoding = get_text_encoding([text], dictionary)
    return [decision_tree.predict(text_encoding)[0], 
            naive_bayes.predict(text_encoding)[0], 
            dnn.predict(text_encoding)[0], predicted_label]

print(predict(''))
# Out:
# ['嘻嘻', '抓狂', '鼓掌', '回复', '偷笑', '一个', 'cn', 'http', '可爱', '开心', '北京', '转发', '中国', '喜欢', '谢谢', '真的', '...', '朋友', '美食', '呵呵', '威武', 'good', '老师', '围观', '旅游', '馋嘴', '酒店', '时间', '哈哈哈', '生活', '终于', '感谢', '希望', '失望', '微博', '孩子', '不错', '吃惊', '幸福', '亲亲', '期待', '支持', '悲伤', '世界', '发现', '可怜', '感觉', '花心', '快乐', '活动', '上海', '关注', '抱抱', '回来', '很多', '好吃', '同学', '伤心', '照片', '回家', '居然', '妈妈', '旅行', '小时', '鼻屎', '感动', '地方', '工作', '东西', '怒骂', '分享', '推荐', '手机', '思考', '加油', '餐厅', '两个', '特别', '只能', '蜡烛', '官方', '害羞', '恭喜', '记得', '机会', '味道', '电影', '童鞋', '超级', '美女', '兔子', '赶紧', '咖啡', '公司', '睡觉', '委屈', '真心', '人生', '心情', '蛋糕', '礼物', '男人', '好好', '话筒', '美丽', '新浪', '全球', '告诉', '生病', '女人', '节目', '努力', '不到', '吃货', '参加', '可惜', '摄影', '好像', '亲们', '看着', '实在', '吃饭', '不了', '现场', '估计', '确实', '鄙视', '竟然', '路上', '还要', '亲爱', '几天', '永远', '围脖', '一点', '小伙伴', '飞机', '电话', '辛苦', '神马', '太阳', '一句', '姐姐', '几个', '到底', '第一次', '演员', '不用', '美好', '上班', '国际', '一种', '阳光', '享受', '肯定', '小姐', '创意', '精彩', '时尚', '第一', '姑娘', '学习', '事情', '漂亮', '不想', '好多', '故事', '越来越', '笑哈哈', '欢乐', '体验', '祝福', '收到', '日子', '找到', '不好', '天下', '文化', '国家', '爱心', '奥特曼', '事儿', '一年', '健康', '音乐', '想起', '粉丝', '哈哈哈哈', '一张', '成功', '城市', '香港', '新闻', '宝宝', '马上', '天气', '好看', '出门', '视频', '美国', '杂志', '日本', '不行', '....', '难道', '就要', '生日快乐', '尼玛', '免费', '社会', '人民', '熊猫', '图片', '美味', '刚刚', '......', '值得', '媒体', '握手', '相声', '情况', '老板', '微信', '地址', '早安', '摄影师', '宝贝', '私信', '才能', '名字', '厦门', '家里', '生命', '经典', '据说', '导演', '结束', '爱情', '有没有', '爸爸', '适合', '广告', '自由', '梦想', '搞笑', '兄弟', '服务', '衣服', '小小', '减肥', '广州', '传递', '疑问', '机场', '一只', '温暖', '设计', '身边', '想要', '评论', '黑线', '直播', '再次', '感受', '错过', '声音', '三个', '台湾', '选择', '小心', '一位', '简单', '儿子', '两天', '南京', '同事', '领导', '不知', '一路', '品牌', '来自', '记者', '羡慕', '回去', '试试', '老公', '想到', '发生', '深圳', '眼睛', '还好', '我会', '火锅', '惊喜', '浮云', '明白', '大师', '貌似', '晚安', '简直', '多多', '分钟', '成都', '一条', '..', '身体', '厉害', '地铁', '旅游局', '口味', '哥哥', '做鬼脸', '建议', '感冒', '卫视', '新鲜', '提前', '木有', '听说', '节奏', '度假', '作品', '自然', '样子', '哼哼', '时代', '完美', '时光', '专业', '中心', '狗狗', '带来', '浪漫', '精选', '律师', '一家', '拍照', '天津', '右边', '参与', '微风', '青春', '阴险', '早餐', '见到', '医院', '帮忙', '全国', '纠结', '计划', '出发', 'de', '可怕', '最爱', '休息', '动物', '星座', '杭州', '听到', '包袱', '下班', '小时候', '精神', '疯狂', '得意', '胖子', '拍摄', '干嘛', '啊啊啊', '政府', '平安', '提供', '旁边', '激动', '艺术', '作家', '加班', '不少', '忘记', '年轻', '起床', '重庆', 'DJ', '一份', '汽车', '方式', '怀念', '不让', '等待', '父母', '去过', '明星', '历史', '回到', '好友', '传说', '幸运', '真相', '空间', '产品', '行者', '嘿嘿', '东方', '恐怖', '环境', '.....', '一场', '晚餐', '餐饮', '依然', '小朋友', '说话', '风景', '叔叔', '即将', '更好', '回忆', '厨房', '扩散', '想念', '老婆', '苹果', '发布', '办法', '排行榜', '便宜', '女儿', '月亮', '组织', '三亚', '干杯', '主持人', '信息', '挤眼', '价格', '下雨', '电脑', '司机', '半天', '家人', '影响', '电视', '原因', '眼泪', '消息', '舒服', '多年', '婚礼', '小米', '报名', '天空', '提醒', '能量', '妹妹', '师傅', '大叔', '愉快', '讨厌', '文艺', '同意', '看过', '帅哥', '玫瑰', '中奖', '安排', '演出', '国内', '教育', '系列', '特色', '结婚', '学校', '反正', '好玩', '不起', '帝都', '网友', '新疆', '保护', '微笑', '互联网', '点儿', '淘宝', '唯一', '包子', '海南', '巧克力', '理解', '__', '天堂', '速度', '表情', '代表', '再也', '医生', '打开', '祝贺', '开车', '一生', '大哥', '没想到', '关系', '多谢', '编辑', '##', '娱乐', '集团', '链接', '警察', '是因为', '不吃', '女孩', '遗憾', '大学', '想想', '空气', '没事', '品尝', '离开', '外面', '主题', '有意思', '天使', '传统', '失眠', '京城', '担心', '两位', '形象', '歌手', '震惊', '一把', '鲜花', '效果', '一周', '高级', '网络', '清新', '韩国', '来说', '市场', '表演', '长大', 'PS', '无敌', '热情', '睡不着', '电台', '央视', '半夜', '闭嘴', '天涯', '第一个', '报道', '大爷', 'ing', '福利', '真实', '传媒', '介绍', '大人', '最美', '经历', '对不起', '不好意思', '来看', '阿姨', '攻略', '泰国', '送给', '冷笑', '请问', '正式', '默默', '好人', '关键', '云南', '人类', '同志', '就算', '老人', '折腾', '发展', '广播', '姐妹', '快递', '客人', '慢慢', '精品', '打电话', '团队', '记忆', '管理', '接受', '海鲜', '肚子', 'BTV', '主人', '习惯', '任志强', '比赛', '在线', '四个', '地球', '笑星', '赶快', '企业', '观众', '百度', '排队', '难受', '俱乐部', '学生', '盆友', '研究', '技术', '痛苦', '猫猫', '风格', '专家', '颜色', '淡定', '喝酒', '一件', '美的', '造型', '心中', '打算', '成长', '收藏', '员工', '出版', '相机', '人性', '力量', '美景', '通知', '优惠', '公布', '娃娃', '推出', '运动', '办公室', '温馨', '老妈', '放心', '身上', '文字', '也许', '神奇', '现实', '懒人', '四川', '郁闷', '内容', '广东', '诱惑', '回覆', '压 ...
# 加载模型: param/decision_tree_model.pth
# 加载模型: param/naive_bayes_model.pth
# 加载模型: param/dnn_model.pth
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\28495\AppData\Local\Temp\jieba.cache
# Loading model cost 0.351 seconds.
# Prefix dict has been built successfully.
# [0, 0, tensor(1), 1]
# d:\Desktop\nlp\model\DNN.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = F.softmax(out)
